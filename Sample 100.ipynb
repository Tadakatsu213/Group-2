# %%
import pandas as pd

file_path = r"C:\Users\tadak\OneDrive\Desktop\Data analysis\work\Challenge\Project\project\Folder\case_death_test_dataset.csv"
data = pd.read_csv(file_path)

# Extract the first 100 
first_100_data = data.iloc[:100, :]

first_100_data
# Out:
#    WHO_REGION                      COUNTRY_NAME COUNTRY_CODE  ISO_YEAR  \
# 0         AFR                      South Africa          ZAF      2020
# 1         AFR                      South Africa          ZAF      2020
# 2         AFR                      South Africa          ZAF      2020
# 3         AFR                      South Africa          ZAF      2020
# 4         AFR                      South Africa          ZAF      2020
# ..        ...                               ...          ...       ...
# 95        AFR  Democratic Republic of the Congo          COD      2020
# 96        AFR  Democratic Republic of the Congo          COD      2020
# 97        AFR  Democratic Republic of the Congo          COD      2020
# 98        AFR  Democratic Republic of the Congo          COD      2020
# 99        AFR  Democratic Republic of the Congo          COD      2020
#
#     ISO_WEEK ISO_START_DATE     SEX AGEGROUP  AGEGROUP_NUM  DAILY_CASES  ...  \
# ...
